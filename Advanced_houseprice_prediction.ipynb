# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
path="/content/Housing-project-train-data.csv"
df=pd.read_csv(path)
df.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.isnull(df).head()
# Out:
#       Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  False       False     False         True    False   False   True     False
# 1  False       False     False        False    False   False   True     False
# 2  False       False     False        False    False   False   True     False
# 3  False       False     False        False    False   False   True     False
# 4  False       False     False         True    False   False   True     False
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0        False      False  ...     False    True   True         True    False
# 1        False      False  ...     False    True   True         True    False
# 2        False      False  ...     False    True   True         True    False
# 3        False      False  ...     False    True  False         True    False
# 4        False      False  ...     False    True   True         True    False
#
# ...

# %%
df.sort_values(["Id"],axis=0,ascending=[True],inplace=True)
df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 427   1          60       RL         65.0     8450   Pave   NaN      Reg
# 146   2          20       RL         80.0     9600   Pave   NaN      Reg
# 102   3          60       RL         68.0    11250   Pave   NaN      IR1
# 143   4          70       RL         60.0     9550   Pave   NaN      IR1
# 280   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 427         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 146         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 102         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 143         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 280         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df[pd.isnull(df).any(axis=1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 427      1          60       RL         65.0     8450   Pave   NaN      Reg
# 146      2          20       RL         80.0     9600   Pave   NaN      Reg
# 102      3          60       RL         68.0    11250   Pave   NaN      IR1
# 143      4          70       RL         60.0     9550   Pave   NaN      IR1
# 280      5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 584   1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1092  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1144  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 22    1459          20       RL         68.0     9717   Pave   NaN      Reg
# 309   1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### 1.Missing values

# %%
## listing out all the features with a missing value
features_with_na=[features for features in df.columns
                  if df[features].isnull().sum()>1]

# %%
## checking the percentage of missing values in each feature
for feature in features_with_na:
    print(feature, np.round(df[feature].isnull().mean(),2))
# Out:
# LotFrontage 0.18
# Alley 0.93
# MasVnrType 0.01
# MasVnrArea 0.01
# BsmtQual 0.03
# BsmtCond 0.03
# BsmtExposure 0.03
# BsmtFinType1 0.03
# BsmtFinType2 0.03
# FireplaceQu 0.47
# GarageType 0.05
# GarageYrBlt 0.05
# GarageFinish 0.05
# GarageQual 0.05
# GarageCond 0.05
# PoolQC 0.99
# Fence 0.8
# MiscFeature 0.96

# %%
## checking the relationship of features with the dependent variable in this case,it is the Sales Price
for feature in features_with_na:
    df2=df.copy()
    df2[feature]=np.where(df2[feature].isnull(),1,0)
    ## 1 indicates NaN value else it is 0
    df2.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### 2.Numerical Variables

# %%
## listing all the numerical features present in the dataframe
numerical_features=[feature for feature in df.columns
                   if df[feature].dtype!='O']
print('Number of numerical variables: ',len(numerical_features))
df[numerical_features].head()
# Out:
# Number of numerical variables:  38
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 427   1          60         65.0     8450            7            5
# 146   2          20         80.0     9600            6            8
# 102   3          60         68.0    11250            7            5
# 143   4          70         60.0     9550            7            5
# 280   5          60         84.0    14260            8            5
#
#      YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# 427       2003          2003       196.0         706  ...           0
# 146       1976          1976         0.0         978  ...         298
# 102       2001          2002       162.0         486  ...           0
# 143       1915          1970         0.0         216  ...           0
# 280       2000          2000       350.0         655  ...         192
#
#      OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
## exploring the temporal variables and its data
year_features=[feature for feature in numerical_features
               if 'Yr' in feature or 'Year' in feature]
for feature in year_features:
    print(feature,df[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 2004 1973 1939 2005 1962 2006 1960 1929 1967
#  1958 1930 2002 2007 1951 1920 1966 1959 1994 1955 1965 1983 1997 1934
#  1981 1999 1972 1921 1970 1945 1953 1998 1954 1956 1948 1968 1910 1995
#  1991 1950 1961 1993 1977 1985 1979 2009 1931 1990 1969 1935 1988 1971
#  1952 1963 1936 1975 1923 1924 1984 1940 1941 1986 2008 1957 1908 1892
#  1916 1932 1918 1912 1947 1964 1925 1980 1982 1989 1992 1949 1880 1978
#  1922 2010 1928 1996 1927 1946 1926 1913 1937 1942 1900 1974 1893 1914
#  1906 1987 1898 1904 1890 1882 1938 1875 1911 1917 1919 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 2005 1973 1950 2006 1962 2007 1960 2001 1967
#  1965 2008 1959 1995 1955 1983 1997 1987 1972 2004 1996 1998 1989 1953
#  1956 1968 1981 1992 1982 1961 1993 1999 1985 1979 2009 1977 1990 1969
#  1958 1966 1991 1971 1952 1963 1975 2010 1984 1986 1994 1964 1980 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
## visualising the relationship b/w year features with SalePrice
for feature in year_features:
    if feature!='YrSold':
        df3=df.copy()
        df3[feature]=df3['YrSold']-df3[feature]
        plt.scatter(df3[feature],df3['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %%
## exploring the discrete numerical features
discrete_features=[feature for feature in numerical_features
                  if len(df[feature].unique())<25 and feature not in
                  year_features+['Id']]
print('Number of Discrete Variables:',len(discrete_features))
discrete_features
# Out:
# Number of Discrete Variables: 17
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
## visualising relationship between discrete variables and SalePrice
for feature in discrete_features:
    df1=df.copy()
    df1.groupby(feature)['SalePrice'].median().plot.bar()
    plt.ylabel('SalePrice')
    plt.xlabel(feature)
    plt.title(feature)
    plt.show()

# %%
## exploring the continous numerical features
continous_features=[feature for feature in numerical_features
                   if feature not in discrete_features+year_features+['Id']]
print('Number of continous variables:',len(continous_features))
continous_features
# Out:
# Number of continous variables: 16
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
## visualising continous variables
for feature in continous_features:
    df1=df.copy()
    df1[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.title(feature)
    plt.show()

# %% [markdown]
# Logarithmic transformations for continous variables

# %%
for feature in continous_features:
    df1=df.copy()
    if 0 in df1[feature].unique():
        pass
    else:
        df1[feature]=np.log(df1[feature])
        df1['SalePrice']=np.log(df1['SalePrice'])
        plt.scatter(df1[feature],df1['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.title(feature)
        plt.show()

# %% [markdown]
# ### 3.Outliers

# %%
for feature in continous_features:
    df1=df.copy()
    if 0 in df1[feature].unique():
        pass
    else:
        df1[feature]=np.log(df1[feature])
        df1.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# ### 4.Categorical Feature

# %%
categorical_features=[feature for feature in df.columns
                     if df[feature].dtype=='O']
print('Number of Categorical Features:', len(categorical_features))
categorical_features
# Out:
# Number of Categorical Features: 43
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
## finding the number of categories for each categorical feature
for feature in categorical_features:
    print('For feature {} number of categories are {}'.format(feature,len(df[feature].unique())))
# Out:
# For feature MSZoning number of categories are 5
# For feature Street number of categories are 2
# For feature Alley number of categories are 3
# For feature LotShape number of categories are 4
# For feature LandContour number of categories are 4
# For feature Utilities number of categories are 1
# For feature LotConfig number of categories are 5
# For feature LandSlope number of categories are 3
# For feature Neighborhood number of categories are 25
# For feature Condition1 number of categories are 9
# For feature Condition2 number of categories are 8
# For feature BldgType number of categories are 5
# For feature HouseStyle number of categories are 8
# For feature RoofStyle number of categories are 6
# For feature RoofMatl number of categories are 8
# For feature Exterior1st number of categories are 14
# For feature Exterior2nd number of categories are 15
# For feature MasVnrType number of categories are 5
# For feature ExterQual number of categories are 4
# ...

# %%
## visualising the relationship between categorical features and SalePrice
for feature in categorical_features:
    df1=df.copy()
    df1.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Handlling missing values

# %%
## handling categorical features with missing values
features_nan=[feature for feature in df.columns if
             df[feature].isnull().sum()>1 and df[feature].dtypes=='O']
for feature in features_nan:
    print('For feature {} missing value is {}'.format(feature,np.round(df[feature].isnull().mean(),2)))
# Out:
# For feature Alley missing value is 0.93
# For feature MasVnrType missing value is 0.01
# For feature BsmtQual missing value is 0.03
# For feature BsmtCond missing value is 0.03
# For feature BsmtExposure missing value is 0.03
# For feature BsmtFinType1 missing value is 0.03
# For feature BsmtFinType2 missing value is 0.03
# For feature FireplaceQu missing value is 0.47
# For feature GarageType missing value is 0.05
# For feature GarageFinish missing value is 0.05
# For feature GarageQual missing value is 0.05
# For feature GarageCond missing value is 0.05
# For feature PoolQC missing value is 0.99
# For feature Fence missing value is 0.8
# For feature MiscFeature missing value is 0.96

# %%
## replacing the NaN values with some other value
def missing_categorical(df,features_nan):
    df1=df.copy()
    df1[features_nan]=df1[features_nan].fillna("Missing")
    return df1

df=missing_categorical(df,features_nan)
df[features_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
## handling numerical values with missing values
numerical_nan=[feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtypes!='O']
for feature in numerical_nan:
    print(" Feature {} has {}% missing value".format(feature,np.around(df[feature].isnull().mean(),4)))
# Out:
#  Feature LotFrontage has 0.1832% missing value
#  Feature MasVnrArea has 0.006% missing value
#  Feature GarageYrBlt has 0.0548% missing value

# %%
## replacing numerical missing values with median
for feature in numerical_nan:
    median_val=df[feature].median()
for feature in numerical_nan:
    df[feature+'nan']=np.where(df[feature].isnull,1,0)
    df[feature].fillna(median_val,inplace=True)
df[numerical_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
## replacing the value of temporal variables with respect to year sold
for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
    df[feature]=df['YrSold']-df[feature]

# %%
df[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#      YearBuilt  YearRemodAdd  GarageYrBlt
# 427          5             5          5.0
# 146         31            31         31.0
# 102          7             6          7.0
# 143         91            36          8.0
# 280          8             8          8.0

# %% [markdown]
# ### Handling skewed numerical features/ outliers

# %%
for feature in 'LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice' :
    df[feature]=np.log(df[feature])

# %%
df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 427   1          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 146   2          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 102   3          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 143   4          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 280   5          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#     LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# 427         Lvl    AllPub  ...     Missing       0      2   2008       WD
# 146         Lvl    AllPub  ...     Missing       0      5   2007       WD
# 102         Lvl    AllPub  ...     Missing       0      9   2008       WD
# 143         Lvl    AllPub  ...     Missing       0      2   2006       WD
# 280         Lvl    AllPub  ...     Missing       0     12   2008       WD
#
# ...

# %% [markdown]
# ### Handling rare categorical values

# %%
categorical_features=[feature for feature in df.columns if df[feature].dtype=='O']
for feature in categorical_features:
    temp=df.groupby(feature)['SalePrice'].count()/len(df)
    temp_df=temp[temp>0.01].index
    df[feature]=np.where(df[feature].isin(temp_df),df[feature],'rare')

# %%
df.head(10)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 427    1          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 146    2          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 102    3          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 143    4          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 280    5          60       RL     4.430817  9.565214   Pave  Missing      IR1
# 291    7          20       RL     4.317488  9.218705   Pave  Missing      Reg
# 1090   8          60       RL     7.590852  9.247829   Pave  Missing      IR1
# 363   10         190       RL     3.912023  8.911934   Pave  Missing      Reg
# 193   12          60       RL     4.442651  9.386308   Pave  Missing      IR1
# 416   13          20       RL     7.590852  9.470240   Pave  Missing      IR2
#
#      LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# ...

# %% [markdown]
# ### Label Encoding of the categorical variables

# %%
for feature in categorical_features:
    label=df.groupby(feature)['SalePrice'].mean().sort_values().index
    label={k:i for i,k in enumerate(label,0)}
    df[feature]=df[feature].map(label)

# %%
df.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 427   1          60         3     4.174387  9.041922       1      2         0
# 146   2          20         3     4.382027  9.169518       1      2         0
# 102   3          60         3     4.219508  9.328123       1      2         1
# 143   4          70         3     4.094345  9.164296       1      2         1
# 280   5          60         3     4.430817  9.565214       1      2         1
#
#      LandContour  Utilities  ...  MiscFeature  MiscVal  MoSold  YrSold  \
# 427            1          0  ...            1        0       2    2008
# 146            1          0  ...            1        0       5    2007
# 102            1          0  ...            1        0       9    2008
# 143            1          0  ...            1        0       2    2006
# 280            1          0  ...            1        0      12    2008
#
# ...

# %% [markdown]
# ### Feature Scaling

# %%
scale_feature=[feature for feature in df.columns if feature not in ['Id','SalePrice']]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(df[scale_feature])
# Out:
# MinMaxScaler()

# %%
scaler.transform(df[scale_feature])
# Out:
# array([[0.23529412, 0.75      , 0.24852241, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.29419428, ..., 0.        , 0.        ,
#         0.        ],
#        [0.23529412, 0.75      , 0.258447  , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.29411765, 0.75      , 0.25188061, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.258447  , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.27999854, ..., 0.        , 0.        ,
#         0.        ]])

# %% [markdown]
# ## Applying Feature Engineering on testing dataset

# %%
path_1="/content/Housing-project-train-data.csv"
df1=pd.read_csv(path_1)
df1.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
## handling categorical features with missing values
features_nan=[feature for feature in df1.columns if
             df1[feature].isnull().sum()>1 and df1[feature].dtypes=='O']
for feature in features_nan:
    print('For feature {} missing value is {}'.format(feature,np.round(df1[feature].isnull().mean(),2)))
# Out:
# For feature Alley missing value is 0.93
# For feature MasVnrType missing value is 0.01
# For feature BsmtQual missing value is 0.03
# For feature BsmtCond missing value is 0.03
# For feature BsmtExposure missing value is 0.03
# For feature BsmtFinType1 missing value is 0.03
# For feature BsmtFinType2 missing value is 0.03
# For feature FireplaceQu missing value is 0.47
# For feature GarageType missing value is 0.05
# For feature GarageFinish missing value is 0.05
# For feature GarageQual missing value is 0.05
# For feature GarageCond missing value is 0.05
# For feature PoolQC missing value is 0.99
# For feature Fence missing value is 0.8
# For feature MiscFeature missing value is 0.96

# %%
## replacing the NaN values with some other value
def missing_categorical(df1,features_nan):
    df2=df1.copy()
    df2[features_nan]=df2[features_nan].fillna("Missing")
    return df2

df1=missing_categorical(df1,features_nan)
df1[features_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
## handling numerical values with missing values
numerical_nan=[feature for feature in df1.columns if df1[feature].isnull().sum()>1 and df1[feature].dtypes!='O']
for feature in numerical_nan:
    print(" Feature {} has {}% missing value".format(feature,np.around(df1[feature].isnull().mean(),4)))
# Out:
#  Feature LotFrontage has 0.1832% missing value
#  Feature MasVnrArea has 0.006% missing value
#  Feature GarageYrBlt has 0.0548% missing value

# %%
## replacing numerical missing values with median
for feature in numerical_nan:
    median_val=df1[feature].median()
for feature in numerical_nan:
    df1[feature+'nan']=np.where(df1[feature].isnull,1,0)
    df1[feature].fillna(median_val,inplace=True)
df1[numerical_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
## replacing the value of temporal variables with respect to year sold
for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
    df1[feature]=df1['YrSold']-df1[feature]

# %%
for feature in 'LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice' :
    df1[feature]=np.log(df1[feature])

# %%
categorical_features=[feature for feature in df1.columns if df1[feature].dtype=='O']
for feature in categorical_features:
    temp=df1.groupby(feature)['SalePrice'].count()/len(df)
    temp_df1=temp[temp>0.01].index
    df1[feature]=np.where(df1[feature].isin(temp_df),df1[feature],'rare')

# %%
for feature in categorical_features:
    label=df1.groupby(feature)['SalePrice'].mean().sort_values().index
    label={k:i for i,k in enumerate(label,0)}
    df1[feature]=df1[feature].map(label)

# %%
df1.head()
# Out:
#     Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0  127         120         0     7.590852  8.502689       0      0         0
# 1  889          20         0     4.553877  9.671871       0      0         0
# 2  793          60         0     4.521789  9.202308       0      0         0
# 3  110          20         0     4.653960  9.371694       0      0         0
# 4  422          20         0     7.590852  9.719264       0      0         0
#
#    LandContour  Utilities  ...  MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0          0  ...            0        0       2    2007
# 1            0          0  ...            0        0      10    2007
# 2            0          0  ...            0        0       6    2007
# 3            0          0  ...            0        0       1    2010
# 4            0          0  ...            0        0       6    2009
#
#    SaleType  SaleCondition  SalePrice  LotFrontagenan  MasVnrAreanan  \
# ...

# %%
scale_feature=[feature for feature in df1.columns if feature not in ['Id','SalePrice']]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(df1[scale_feature])
# Out:
# MinMaxScaler()

# %%
scaler.transform(df1[scale_feature])
# Out:
# array([[0.58823529, 0.        , 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.33199406, ..., 0.        , 0.        ,
#         0.        ],
#        [0.23529412, 0.        , 0.32493599, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.82352941, 0.        , 0.02937125, ..., 0.        , 0.        ,
#         0.        ],
#        [0.29411765, 0.        , 0.19081339, ..., 0.        , 0.        ,
#         0.        ],
#        [0.23529412, 0.        , 1.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
df.to_csv('X_train.csv',index=False)

# %%
df1.to_csv('X_test.csv',index=False)

# %%
df=pd.read_csv("X_train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1          60         3     4.174387  9.041922       1      2         0
# 1   2          20         3     4.382027  9.169518       1      2         0
# 2   3          60         3     4.219508  9.328123       1      2         1
# 3   4          70         3     4.094345  9.164296       1      2         1
# 4   5          60         3     4.430817  9.565214       1      2         1
#
#    LandContour  Utilities  ...  MiscFeature  MiscVal  MoSold  YrSold  \
# 0            1          0  ...            1        0       2    2008
# 1            1          0  ...            1        0       5    2007
# 2            1          0  ...            1        0       9    2008
# 3            1          0  ...            1        0       2    2006
# 4            1          0  ...            1        0      12    2008
#
#    SaleType  SaleCondition  SalePrice  LotFrontagenan  MasVnrAreanan  \
# ...

# %%
df_test=pd.read_csv("X_test.csv")

# %%
x_test=df_test.drop(['Id','SalePrice'],axis=1)
y_test=df_test[['SalePrice']]

# %%
x_train=df.drop(['Id','SalePrice'],axis=1)
y_train=df[['SalePrice']]

# %%
y_train=y_train.values

# %%
y_train=y_train.ravel()

# %% [markdown]
# ## Feature selection using Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
feature_sel=SelectFromModel(Lasso(alpha=0.005, random_state=0))
feature_sel.fit(x_train, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
feature_sel.get_support()
# Out:
# array([ True,  True, False,  True, False, False, False, False, False,
#         True, False,  True, False, False, False,  True,  True,  True,
#         True,  True, False, False,  True,  True, False, False, False,
#        False,  True, False, False,  True, False,  True,  True,  True,
#         True,  True, False,  True, False, False,  True,  True,  True,
#        False,  True, False, False, False, False, False,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True, False,
#        False, False,  True,  True,  True,  True,  True,  True, False,
#         True, False, False, False,  True, False,  True, False, False,
#        False])

# %%
selected_feat=x_train.columns[(feature_sel.get_support())]
print('total features: {}'.format((x_train.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
# Out:
# total features: 82
# selected features: 42

# %%
selected_feat
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotArea', 'LotConfig', 'Neighborhood',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'Exterior1st', 'Exterior2nd', 'Foundation', 'BsmtExposure',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'HeatingQC', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'Fence', 'YrSold', 'SaleCondition'],
#       dtype='object')

# %%
x_train=x_train[selected_feat]

# %%
x_train
# Out:
#       MSSubClass  MSZoning   LotArea  LotConfig  Neighborhood  HouseStyle  \
# 0             60         3  9.041922          1            12           6
# 1             20         3  9.169518          0             4           3
# 2             60         3  9.328123          1            12           6
# 3             70         3  9.164296          2            14           6
# 4             60         3  9.565214          0            20           6
# ...          ...       ...       ...        ...           ...         ...
# 1163          20         3  9.753653          1             8           3
# 1164          20         3  9.486076          1            10           3
# 1165          70         3  9.109636          1            14           6
# 1166          20         3  9.181632          1             7           3
# 1167          20         3  9.204020          1             2           3
#
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd  ...  GarageArea  \
# ...

# %%
x_test=x_test[selected_feat]
x_test
# Out:
#       MSSubClass  MSZoning   LotArea  LotConfig  Neighborhood  HouseStyle  \
# 0            120         0  8.502689          0             0           0
# 1             20         0  9.671871          0             0           0
# 2             60         0  9.202308          0             0           0
# 3             20         0  9.371694          0             0           0
# 4             20         0  9.719264          0             0           0
# ...          ...       ...       ...        ...           ...         ...
# 1163          20         0  9.192075          0             0           0
# 1164          20         0  9.079890          0             0           0
# 1165         160         0  7.731931          0             0           0
# 1166          70         0  9.047821          0             0           0
# 1167          60         0  8.969669          0             0           0
#
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd  ...  GarageArea  \
# ...

# %%
y_test
# Out:
#       SalePrice
# 0     11.759786
# 1     12.498742
# 2     12.505399
# 3     12.154779
# 4     12.278393
# ...         ...
# 1163  11.711776
# 1164  11.589887
# 1165  11.908340
# 1166  10.596635
# 1167  12.118334
#
# [1168 rows x 1 columns]

# %% [markdown]
# ## Model Selection

# %%
import xgboost as xg

# %%
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, make_scorer, mean_absolute_error
from sklearn.model_selection import KFold, RandomizedSearchCV

# %%
kf = KFold(n_splits=5, random_state=0, shuffle=True)
rmse = lambda y, y_pred: np.sqrt(mean_squared_error(y, y_pred))
scorer = make_scorer(rmse, greater_is_better=False)

# %%
def random_search(model, grid, n_iter=100):
    if model == xg.XGBRegressor(n_estimators=1000, learning_rate=0.05, n_jobs=4):
        searchxg = RandomizedSearchCV(estimator = model, param_distributions = grid, cv=kf, n_iter = n_iter, n_jobs=4, random_state=0, verbose=True)
        return searchxg.fit(x_train,y_train,early_stopping_rounds=5,verbose=True)
    else:
        search = RandomizedSearchCV(estimator = model, param_distributions = grid, cv=kf, n_iter = n_iter, n_jobs=4, random_state=0, verbose=True)
        return search.fit(x_train, y_train)

# %%
#hyperparameter Grids
xgb_hpg = {'n_estimators': [100, 400, 800],'max_depth': [3, 6, 9],'learning_rate': [0.05, 0.1, 0.20],'min_child_weight': [1, 10, 100]} #XGBoost
ridge_hpg = {"alpha": np.logspace(-1, 2, 500)} #Ridge Regressor
lasso_hpg = {"alpha": np.logspace(-5, -1, 500)} #Lasso Regressor
svr_hpg = {"C": np.arange(1, 100), "gamma": np.linspace(0.00001, 0.001, 50), "epsilon": np.linspace(0.01, 0.1, 50)} #Support Vector Regressor
gbm_hpg = {"max_features": np.linspace(0.2, 0.7, 6), "learning_rate": np.logspace(-3, -1, 100)} #Gradient Boost

# %%
from xgboost import XGBRegressor
xgb_search = random_search(xg.XGBRegressor(n_estimators=1000, n_jobs=4),xgb_hpg) #XGBoost
ridge_search = random_search(Ridge(), ridge_hpg) #Ridge Regressor
lasso_search = random_search(Lasso(), lasso_hpg) #Lasso Regressor
svr_search = random_search(SVR(), svr_hpg,n_iter=100) #Support Vector Regressor
gbm_search = random_search(GradientBoostingRegressor(n_estimators=2000, max_depth=3),gbm_hpg,n_iter=100) #Gradient Boost
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 81 is smaller than n_iter=100. Running 81 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.103e+00, tolerance: 1.843e-02
#   model = cd_fast.enet_coordinate_descent(
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# ---------------------------------------------------------------------------
# ...

# %%
from mlxtend.regressor import StackingCVRegressor
models = [search.best_estimator_ for search in [xgb_search,ridge_search, lasso_search, svr_search]] #list of best estimators from each model
ensemble_search = random_search(StackingCVRegressor(models,Ridge(), cv=kf), {"meta_regressor__alpha": np.logspace(-3, -2, 500)}, n_iter=20) #Ensemble Stack
models.append(ensemble_search.best_estimator_) #list of best estimators from each model including Stack
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.072e-01, tolerance: 1.491e-02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.544e-01, tolerance: 1.447e-02
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
for x in models:
  prediction=x.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but Ridge was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but Lasso was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(

# %%
print(prediction)
# Out:
# [11.39684664 12.14383789 11.96011053 ... 11.47212715 10.84647265
#  11.65283237]

# %%
p=prediction

# %%
my_prediction = pd.DataFrame({"Id": df1.index, "SalePrice": (prediction)})

# %%
my_prediction
# Out:
#         Id  SalePrice
# 0        0  11.396847
# 1        1  12.143838
# 2        2  11.960111
# 3        3  11.808462
# 4        4  11.807823
# ...    ...        ...
# 1163  1163  11.346580
# 1164  1164  11.312449
# 1165  1165  11.472127
# 1166  1166  10.846473
# 1167  1167  11.652832
#
# [1168 rows x 2 columns]

# %%
y_test
# Out:
#       SalePrice
# 0     11.759786
# 1     12.498742
# 2     12.505399
# 3     12.154779
# 4     12.278393
# ...         ...
# 1163  11.711776
# 1164  11.589887
# 1165  11.908340
# 1166  10.596635
# 1167  12.118334
#
# [1168 rows x 1 columns]

# %%
### mean square error
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, prediction)
mse
# Out:
# 0.19406453774440907

# %%
### root mean square error
import numpy as np
rmse = np.sqrt(mean_squared_error(y_test, prediction))
rmse
# Out:
# 0.4405275675192292
